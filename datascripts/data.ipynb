# %% [markdown]
# # PHASE 1 — Structural Sanity Checks

# %%
# !pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in d:\portfolio github\2026\customer behavior early-warning intelligence system\.venv\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in d:\portfolio github\2026\customer behavior early-warning intelligence system\.venv\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\portfolio github\2026\customer behavior early-warning intelligence system\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in d:\portfolio github\2026\customer behavior early-warning intelligence system\.venv\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: tzdata in d:\portfolio github\2026\customer behavior early-warning intelligence system\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\portfolio github\2026\customer behavior early-warning intelligence system\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.1 MB 2.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.1 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.1 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.1 MB 1.8 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.1 MB 1.7 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.1 MB 1.7 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 1.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.1 MB 1.4 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.1 MB 1.4 MB/s eta 0:00:04
#    ------------------- -------------------- 3.9/8.1 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.1 MB 1.4 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.1 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.1 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.1 MB 1.3 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.1 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.8/8.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.2 MB/s eta 0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 1.2 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.2 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.3/2.3 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 1.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.0 MB 1.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.0 MB 1.4 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.0 MB 1.4 MB/s eta 0:00:05
#    -------- ------------------------------- 1.6/7.0 MB 1.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.8/7.0 MB 1.5 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/7.0 MB 1.5 MB/s eta 0:00:04
#    -------------- ------------------------- 2.6/7.0 MB 1.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.1/7.0 MB 1.6 MB/s eta 0:00:03
#    ------------------- -------------------- 3.4/7.0 MB 1.6 MB/s eta 0:00:03
#    -------------------- ------------------- 3.7/7.0 MB 1.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 798.9 kB/s eta 0:00:03
#    ----------------------------- ---------- 5.2/7.0 MB 817.5 kB/s eta 0:00:03
#    ------------------------------- -------- 5.5/7.0 MB 841.0 kB/s eta 0:00:02
#    ---------------------------------- ----- 6.0/7.0 MB 883.0 kB/s eta 0:00:02
#    ----------------------------------- ---- 6.3/7.0 MB 905.8 kB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 919.4 kB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 938.4 kB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 938.4 kB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 908.5 kB/s eta 0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2 seaborn-0.13.2
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer = pd.read_csv('D:\Portfolio Github\2026\Customer Behavior Early-Warning Intelligence System\synthetic_data\CUSTOMER.csv')
orders = dataframes.get('orders')   
category = dataframes.get('category')
store = dataframes.get('store')
channel = dataframes.get('channel')
session = dataframes.get('session')
orderitem = dataframes.get('orderitem')
product = dataframes.get('product')
support_ticket = dataframes.get('support_ticket')
promotions = dataframes.get('promotions')
campaign = dataframes.get('campaign')
external_factors = dataframes.get('external_factors')

# %% [markdown]
# ## 📌 Dataset Size & Shape
#
# -  Number of customers = 10,000?
#
# -  Number of weeks = 156?
#
# -  Total orders within expected range (280K–420K)?
#
# -  Total order items within expected range?
#
# -  Sessions count reasonable (not exploding)?
#
# -  Support tickets sparse but present?

# %%
# Number of customers
num_customers = customer['customer_id'].nunique() if customer is not None else 0

# Number of weeks (assuming 'orders' has a 'week' or 'order_date' column)
if orders is not None:
    if 'week' in orders.columns:
        num_weeks = orders['week'].nunique()
    elif 'order_date' in orders.columns:
        num_weeks = pd.to_datetime(orders['order_date']).dt.isocalendar().week.nunique()
    else:
        num_weeks = None
else:
    num_weeks = 0

# Total orders
total_orders = orders['order_id'].nunique() if orders is not None else 0

# Total order items
total_order_items = orderitem['order_item_id'].nunique() if orderitem is not None else 0

# Sessions count
session_count = session['session_id'].nunique() if session is not None else 0

# Support tickets present
support_tickets_present = support_ticket['support_ticket_id'].notnull().sum() if support_ticket is not None else 0

print(f"Number of customers: {num_customers}")
print(f"Number of weeks: {num_weeks}")
print(f"Total orders: {total_orders}")
print(f"Total order items: {total_order_items}")
print(f"Sessions count: {session_count}")
print(f"Support tickets present: {support_tickets_present}")
# Out:
# Number of customers: 0
# Number of weeks: 0
# Total orders: 0
# Total order items: 0
# Sessions count: 0
# Support tickets present: 0
